# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import load_boston
boston_datasets = load_boston()

# %%
#WE PUT THE DATA INTO ONE DATA FRAME

# %%
df= pd.DataFrame(boston_datasets.data)

# %%
df
# Out:
#           0     1      2    3      4   ...   8      9     10      11    12
# 0    0.00632  18.0   2.31  0.0  0.538  ...  1.0  296.0  15.3  396.90  4.98
# 1    0.02731   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  396.90  9.14
# 2    0.02729   0.0   7.07  0.0  0.469  ...  2.0  242.0  17.8  392.83  4.03
# 3    0.03237   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  394.63  2.94
# 4    0.06905   0.0   2.18  0.0  0.458  ...  3.0  222.0  18.7  396.90  5.33
# ..       ...   ...    ...  ...    ...  ...  ...    ...   ...     ...   ...
# 501  0.06263   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  391.99  9.67
# 502  0.04527   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  9.08
# 503  0.06076   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  5.64
# 504  0.10959   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  393.45  6.48
# 505  0.04741   0.0  11.93  0.0  0.573  ...  1.0  273.0  21.0  396.90  7.88
#
# [506 rows x 13 columns]

# %%
#NOW WE WANT TO PRINT THE FEATURES AND TARGET VALUES OF THE DATA

# %%
df= pd.DataFrame(boston_datasets.data, columns= boston_datasets.feature_names)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %%
boston_datasets
# Out:
# {'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate
# ...

# %%
#FOR THE TARGET VALUES

# %%
print('prices: {}'.format(boston_datasets.target))
# Out:
# prices: [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
boston_datasets.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
#REPLACING THE TARGET VALUE WITH PRICE

# %%
df= pd.DataFrame(boston_datasets.data, columns=boston_datasets.feature_names)
df['Price']= boston_datasets.target

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  Price
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67   22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08   20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64   23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48   22.0
# ...

# %%
# SPLITTING THE DATA INTO TRAINING and EVALUATING DATA

# %%
from sklearn.model_selection import train_test_split
x= df.loc[ :, df.columns != 'Price']#training data
y= df.loc[:, df.columns == 'Price']#testing data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=123)

# %%
#DETERMINING THE INPUTS, HIDDEN LAYERS AND OUTPUTA

# %%
from keras.models import Sequential
from keras.layers import Dense
model= Sequential()
model.add(Dense(128, input_shape=(13, ), activation= 'relu', name= 'dense_layer_1'))
model.add(Dense(64, activation= 'relu', name= 'dense_layer_2'))
model.add(Dense(1, activation='linear', name='dense_output'))

# %%
#MODEL COMPILATION

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_layer_1 (Dense)        (None, 128)               1792
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 64)                8256
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 65
# ...
# Total params: 10,113
# Trainable params: 10,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
#TRAINING

# %%
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 2ms/step - loss: 13.3717
# Epoch 2/100
# 12/12 [==============================] - 0s 2ms/step - loss: 13.7155
# Epoch 3/100
# 12/12 [==============================] - 0s 2ms/step - loss: 23.2347
# Epoch 4/100
# 12/12 [==============================] - 0s 2ms/step - loss: 17.3922
# Epoch 5/100
# 12/12 [==============================] - 0s 2ms/step - loss: 13.7085
# Epoch 6/100
# 12/12 [==============================] - 0s 2ms/step - loss: 15.8925
# Epoch 7/100
# 12/12 [==============================] - 0s 2ms/step - loss: 14.5845
# Epoch 8/100
# 12/12 [==============================] - 0s 2ms/step - loss: 23.3272
# Epoch 9/100
# 12/12 [==============================] - 0s 2ms/step - loss: 17.1233
# Epoch 10/100
# 12/12 [==============================] - 0s 2ms/step - loss: 21.2637
# Epoch 11/100
# 12/12 [==============================] - 0s 2ms/step - loss: 16.4261
# Epoch 12/100
# ...

# %%
#MODEL EVALUATION

# %%
loss= model.evaluate(x_test, y_test)
print('Mean square error on test data:', loss)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 20.5419
# Mean square error on test data: 20.541885375976562
